# %%
EDA_Titanic.ipynb

# %%
titanic.csv

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inside notebook
# %matplotlib inline

# Load the dataset
df = pd.read_csv("titanic.csv")

# Display first 5 rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Import required libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#      61     Int8Dtype,
#      62     Int16Dtype,
#      63     Int32Dtype,
#      64     Int64Dtype,
#      65     UInt8Dtype,
#      66     UInt16Dtype,
#      67     UInt32Dtype,
#      68     UInt64Dtype,
#      69     Float32Dtype,
#      70     Float64Dtype,
#      71     CategoricalDtype,
#      72     PeriodDtype,
#      73     IntervalDtype,
#      74     DatetimeTZDtype,
#      75     StringDtype,
#      76     BooleanDtype,
#      77     # missing
#      78     NA,
#      79     isna,
#      80     isnull,
#      81     notna,
#      82     notnull,
#      83     # indexes
#      84     Index,
#      85     CategoricalIndex,
#      86     RangeIndex,
#      87     MultiIndex,
#      88     IntervalIndex,
#      89     TimedeltaIndex,
#      90     DatetimeIndex,
#      91     PeriodIndex,
#      92     IndexSlice,
#      93     # tseries
#      94     NaT,
#      95     Period,
#      96     period_range,
#      97     Timedelta,
#      98     timedelta_range,
#      99     Timestamp,
#     100     date_range,
#     101     bdate_range,
#     102     Interval,
#     103     interval_range,
#     104     DateOffset,
#     105     # conversion
#     106     to_numeric,
#     107     to_datetime,
#     108     to_timedelta,
#     109     # misc
#     110     Flags,
#     111     Grouper,
#     112     factorize,
#     113     unique,
#     114     NamedAgg,
#     115     array,
#     116     Categorical,
#     117     set_eng_float_format,
#     118     Series,
#     119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#     123 from pandas.core.dtypes.dtypes import SparseDtype
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\api.py:46
#      44 from pandas.core.construction import array  # noqa: ICN001
#      45 from pandas.core.flags import Flags
# ---> 46 from pandas.core.groupby import (
#      47     Grouper,
#      48     NamedAgg,
#      49 )
#      50 from pandas.core.indexes.api import (
#      51     CategoricalIndex,
#      52     DatetimeIndex,
#    (...)     58     TimedeltaIndex,
#      59 )
#      60 from pandas.core.indexes.datetimes import (
#      61     bdate_range,
#      62     date_range,
#      63 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\groupby\__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\groupby\generic.py:64
#      57 from pandas.core.apply import (
#      58     GroupByApply,
#      59     maybe_mangle_lambdas,
#      60     reconstruct_func,
#      61     validate_func_kwargs,
#      62 )
#      63 import pandas.core.common as com
# ---> 64 from pandas.core.frame import DataFrame
#      65 from pandas.core.groupby import base
#      66 from pandas.core.groupby.groupby import (
#      67     GroupBy,
#      68     GroupByPlot,
#      69 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:154
#     150     ensure_wrapped_if_datetimelike,
#     151     sanitize_array,
#     152     sanitize_masked_array,
#     153 )
# --> 154 from pandas.core.generic import NDFrame
#     155 from pandas.core.indexers import check_key_length
#     156 from pandas.core.indexes.api import (
#     157     DatetimeIndex,
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py:145
#     141     isna,
#     142     notna,
#     143 )
#     144
# --> 145 from pandas.core import (
#     146     algorithms as algos,
#     147     arraylike,
#     148     common,
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexing.py:74
#      64 from pandas.core.construction import (
#      65     array as pd_array,
#      66     extract_array,
#      67 )
#      68 from pandas.core.indexers import (
#      69     check_array_indexer,
#      70     is_list_like_indexer,
#      71     is_scalar_indexer,
#      72     length_of_indexer,
#      73 )
# ---> 74 from pandas.core.indexes.api import (
#      75     Index,
#      76     MultiIndex,
#      77 )
#      79 if TYPE_CHECKING:
#      80     from collections.abc import (
#      81         Hashable,
#      82         Sequence,
#      83     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\api.py:19
#      16 from pandas.core.dtypes.cast import find_common_type
#      18 from pandas.core.algorithms import safe_sort
# ---> 19 from pandas.core.indexes.base import (
#      20     Index,
#      21     _new_Index,
#      22     ensure_index,
#      23     ensure_index_from_sequences,
#      24     get_unanimous_names,
#      25     maybe_sequence_to_range,
#      26 )
#      27 from pandas.core.indexes.category import CategoricalIndex
#      28 from pandas.core.indexes.datetimes import DatetimeIndex
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:29
#      21 import numpy as np
#      23 from pandas._config import (
#      24     get_option,
#      25     is_nan_na,
#      26     using_string_dtype,
#      27 )
# ---> 29 from pandas._libs import (
#      30     NaT,
#      31     algos as libalgos,
#      32     index as libindex,
#      33     lib,
#      34     writers,
#      35 )
#      36 from pandas._libs.internals import BlockValuesRefs
#      37 import pandas._libs.join as libjoin
#
# File <frozen importlib._bootstrap>:645, in ModuleSpec.parent(self)
# --> 645 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv("titanic.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 import seaborn as sns
#       5
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       7
# ----> 8 df = pd.read_csv("titanic.csv")
#       9 df.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'titanic.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Dataset Information
print("Shape of Dataset:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nDataset Info:")
df.info()

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Shape of Dataset: (891, 12)
#
# Columns:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
#
# Statistical Summary:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Missing Values
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Duplicate Rows
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# Fill missing values

# Fill Age with median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Fill Embarked with mode
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Drop Cabin column because it has many missing values
df.drop('Cabin', axis=1, inplace=True)

# Check missing values again
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64
# C:\Users\MURALI KRISHNA\AppData\Local\Temp\ipykernel_14520\2564479200.py:4: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# C:\Users\MURALI KRISHNA\AppData\Local\Temp\ipykernel_14520\2564479200.py:7: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
import matplotlib.pyplot as plt

# Age Distribution
plt.figure(figsize=(8,5))
plt.hist(df['Age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(x='Survived', data=df)
plt.title("Survival Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Sex', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Distribution")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df.select_dtypes(include='number').corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Fare'], bins=30)
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()

# %%
df.to_csv("Titanic_Cleaned.csv", index=False)
print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
df.to_csv("Titanic_Cleaned.csv", index=False)
print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles in this folder:")
print(os.listdir())
# Out:
# Current Folder:
# C:\Users\MURALI KRISHNA
#
# Files in this folder:
# ['.copilot', '.ipynb_checkpoints', '.ipython', '.jupyter', '.vscode', '.vscode-shared', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'CrossDevice', 'Documents', 'Downloads', 'EDA_Titanic.ipynb', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{f4590ab5-d774-11f0-a2e2-f068e3756ad1}.TM.blf', 'NTUSER.DAT{f4590ab5-d774-11f0-a2e2-f068e3756ad1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{f4590ab5-d774-11f0-a2e2-f068e3756ad1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'titanic.csv', 'Titanic_Cleaned.csv', 'Untitled-1.ipynb', 'Untitled-1.py', 'Videos']
